# %%
from train import *

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
import torch

# %%
agent = ProjectAgent()

# %%
avg_sum_rewards, losses = agent.train(env, 500)
# Out:
# Epoch   0 - Reward 8.951e+06
# Epoch   1 - Reward 2.214e+07
# Epoch   2 - Reward 3.190e+06
# Epoch   3 - Reward 3.235e+06
# Epoch   4 - Reward 4.425e+06
# Epoch   5 - Reward 3.412e+06
# Epoch   6 - Reward 3.671e+06
# Epoch   7 - Reward 3.162e+06
# Epoch   8 - Reward 3.166e+06
# Epoch   9 - Reward 3.430e+06

# %%
plt.figure(figsize=(10, 5))
plt.plot(avg_sum_rewards)
plt.title('Average of Rewards')
plt.xlabel('Episode')
plt.ylabel('Rewards')
plt.yscale('log')
plt.show()

# %%
agent.save('/home/gaspard/rl-class-assignment-Clerclus/models/agent.pth')
